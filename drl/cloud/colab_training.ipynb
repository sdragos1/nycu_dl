# %%
# !git clone https://github.com/sdragos1/nycu_dl.git

# %cd nycu_dl/drl

# %%
# !pip install -r requirements.txt

# Alternatively, using uv for faster installation:
# !pip install uv
# !uv pip install --system -r requirements.txt

# %%
import wandb
wandb.login()

# %%
RUN_NAME = "enhanced-double-dqn-per-ms"

# %% [markdown]
# ### Task 1: CartPole DQN

# %%
# !python src/task1.py --wandb-run-name "colab-cartpole"

# %% [markdown]
# ### Task 2: Pong Vanilla DQN

# %%
# !python src/task2.py --wandb-run-name "colab-pong-vanilla"

# %% [markdown]
# ### Task 3: Pong Double DQN / Extensions

# %%
# !python src/task3.py --wandb-run-name "colab-pong-double"
